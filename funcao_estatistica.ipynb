# %% [markdown]
# <a href="https://colab.research.google.com/github/dxdiego5/Analytics-GasPricess-DASHBORD/blob/main/funcao_estatistica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
def f(x):
  return x**2 + 1

x = np.arange(1,10,1)

y = f(x)

print(y)
# Out:
# [ 2  5 10 17 26 37 50 65 82]

# %%
x = np.arange(10,21,0.5)

def f(x):
  return np.sqrt(x+1)

y = f(x)
print(y)
